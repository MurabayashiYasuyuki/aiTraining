# %% [markdown]
# #DAY1 いまいちJupyterNetworkの使い方がわかりません。

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D #3D散布図の描画

# %%
df_fund = pd.read_csv("./Data/ks-projects-201801.csv")[['ID', 'name', 'category', 'main_category', 'currency', 'deadline', 'goal','launched','pledged','state','backers','country','usd pledged','usd_pledged_real','usd_goal_real']]

# データテスト
display(df_fund.head())
df_fund.describe()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...

# %%
pd.plotting.scatter_matrix(df_fund, figsize=(10,10))
plt.show()

# %% [markdown]
# ##なんか動いているのかよくわかりませんがグラフ描画したところで＊のまま何も動かなくなったので放置したまま終わる。７/31 T14:30

# %%
# この後やりたいことーーーーーーーーーーーーーーーーーーー相関係数を確認
df_fund.corr()

# %%
##とりあえず単回帰 
x = df_fund["goal"].values
y = df_fund["state"].values

plt.scatter(x, y, marker='o')
plt.grid(which='major',color='black',linestyle=':')
plt.grid(which='minor',color='black',linestyle=':')
plt.ylabel('state')
plt.xlabel('goal')
plt.show()

# %%
##とりあえず単回帰 
x = df_fund["goal"].values
y = df_fund["usd_goal_real"].values

plt.scatter(x, y, marker='o')
plt.grid(which='major',color='black',linestyle=':')
plt.grid(which='minor',color='black',linestyle=':')
plt.ylabel('usd_goal_real')
plt.xlabel('goal')
plt.show()

# %% [markdown]
# ＃成功するかしないかでロジスティック回帰つくるとしたらいろいろやらんといけない。
# １．Stateをsuccesful=1,それ以外は０にする
# ２．開始からの期間（日付型変換しないと）
# ３．goalの大きさ関係ありそう
# ４．usd_pledged_goalも関係ありそう
# ５．categoryもいれたい。
# どうしたらいいかはわからない。笑
